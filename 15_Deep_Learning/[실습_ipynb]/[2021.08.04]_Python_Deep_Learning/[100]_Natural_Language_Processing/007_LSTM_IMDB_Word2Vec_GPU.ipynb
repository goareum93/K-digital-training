# %% [markdown]
# # IMDB - Word2Vec with LSTM
# > ## NLP(Natural Language Processing)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import Keras

# %% [markdown]
# * Keras Version 확인

# %%
import keras

keras.__version__
# Out:
# '2.4.3'

# %% [markdown]
# # I. IMDB Data_Set

# %% [markdown]
# > ## 1) Load IMDB Data_Set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -l /content/drive/My\ Drive/Colab\ Notebooks/datasets/IMDB.zip
# Out:
# -rw------- 1 root root 60711700 Mar 21 01:09 '/content/drive/My Drive/Colab Notebooks/datasets/IMDB.zip'

# %%
# !unzip /content/drive/My\ Drive/Colab\ Notebooks/datasets/IMDB.zip

# %% [markdown]
# > ## 2) 'texts' and 'labels' Data
#
# * 'texts'  : 문자열 리스트(영화 감상평)
# * 'lebels' : 감상평 리뷰(긍정/부정)

# %%
import os

imdb_dir = 'aclImdb'
train_dir = os.path.join(imdb_dir, 'train')

labels = []
texts = []

for label_type in ['neg', 'pos']:
    dir_name = os.path.join(train_dir, label_type)
    for fname in os.listdir(dir_name):
        if fname[-4:] == '.txt':
            f = open(os.path.join(dir_name, fname), encoding = 'utf8')
            texts.append(f.read())
            f.close()
            if label_type == 'neg':
                labels.append(0)
            else:
                labels.append(1)

# %%
len(labels), len(texts)
# Out:
# (25000, 25000)

# %% [markdown]
# # II. Tensor Transformation

# %% [markdown]
# > ## 1) X_train and X_valid : (25000, 2000)

# %% [markdown]
# * vectorization
#  - (25000, 2000)

# %%
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

maxlen = 2000               # 2000개 단어까지 적용
max_words = 10000           # 빈도 높은 10000개 단어 사용

tokenizer = Tokenizer(num_words = max_words)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

word_index = tokenizer.word_index
print('%s개의 고유한 토큰을 찾았습니다.' % len(word_index))

# (25000, 2000)으로 패딩
data = pad_sequences(sequences, maxlen = maxlen)

labels = np.asarray(labels)
print('데이터 텐서의 크기:', data.shape)
print('레이블 텐서의 크기:', labels.shape)


# 샘플 데이터 랜덤화
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]


# 데이터를 훈련 세트와 검증 세트로 분할
training_samples = 15000            # 훈련 샘플은 15000개
validation_samples = 10000          # 검증 샘플은 10000개

X_train = data[:training_samples]
y_train = labels[:training_samples]
X_valid = data[training_samples: training_samples + validation_samples]
y_valid = labels[training_samples: training_samples + validation_samples]
# Out:
# 88582개의 고유한 토큰을 찾았습니다.
# 데이터 텐서의 크기: (25000, 2000)
# 레이블 텐서의 크기: (25000,)

# %% [markdown]
# # III. Word2Vec
#
# https://tfhub.dev/google/Wiki-words-250-with-normalization/2

# %% [markdown]
# > ## 1) Load Pretrained Word2Vec

# %%
import tensorflow_hub as hub

embeddings_index = hub.load('https://tfhub.dev/google/Wiki-words-250/2')

# %% [markdown]
# * Word2Vec 매핑 확인

# %%
embeddings_index(['apple'])
# Out:
# <tf.Tensor: shape=(1, 250), dtype=float32, numpy=
# array([[-7.81319588e-02, -7.97718316e-02,  1.65636316e-02,
#         -1.08001232e-02, -5.10360440e-03,  1.73767412e-03,
#         -5.22104278e-02, -3.89753021e-02,  3.56903672e-02,
#         -3.47909741e-02, -1.01491222e-02,  1.17565657e-03,
#          1.01802059e-01,  1.75360963e-02,  3.36469710e-02,
#          2.79656947e-02,  9.57141817e-02, -7.82085657e-02,
#          5.06314561e-02, -1.66016668e-01,  2.88206208e-02,
#          6.76635057e-02,  9.70917642e-02,  1.79236010e-02,
#         -5.42766303e-02, -1.56506345e-01, -5.30809052e-02,
#         -1.09254161e-03, -1.59554277e-02, -6.70691356e-02,
#          6.15172908e-02,  4.47090678e-02,  4.07696068e-02,
#         -3.83969024e-02,  6.96176291e-02, -5.60147781e-03,
#         -2.26747449e-02, -3.67878452e-02, -5.66431917e-02,
#         -2.18681507e-02, -8.86453837e-02, -2.22746611e-01,
#         -2.07957737e-02,  8.30694276e-04, -3.93166617e-02,
#          5.93367852e-02,  4.33623493e-02,  2.82799695e-02,
#         -3.33397463e-02,  4.76312377e-02, -1.70567650e-02,
#         -2.29284037e-02, -6.83813961e-03,  9.81669277e-02,
#          1.08622149e-01,  2.33869702e-02,  9.60301422e-03,
#         -5.18808290e-02,  9.87230614e-03, -8.69225897e-03,
#         -7.11247921e-02,  7.64381886e-02, -2.43284814e-02,
#         -1.53728379e-02, -1.62205976e-02,  6.06783573e-03,
#         -7.78824538e-02, -4.63543087e-02, -6.10455871e-02,
#          3.76226790e-02, -3.59688103e-02, -2.22809706e-03,
#          7.61934593e-02, -5.42140864e-02,  8.81553534e-03,
#          1.02721518e-02, -2.33051814e-02,  5.69647923e-02,
#         -1.97233241e-02,  5.40813841e-02, -1.06068708e-01,
#         -4.93893884e-02,  7.71986991e-02,  7.54192844e-02,
#         -9.59494933e-02,  1.31888255e-01, -9.32045653e-02,
#          3.91011648e-02,  9.07641053e-02, -1.92628205e-02,
#         -2.80017368e-02,  1.24782704e-01, -4.39715805e-03,
#         -6.76676631e-02,  4.82756756e-02, -8.52152854e-02,
#          2.47792583e-02, -1.15225026e-02, -5.91450334e-02,
#          5.01944311e-02,  6.20031133e-02, -5.91100939e-02,
#         -6.27844781e-02,  1.29692315e-03, -1.05377071e-01,
#         -9.93670970e-02,  3.99318524e-05,  1.49191227e-02,
#          4.78936266e-03, -1.33457212e-02,  3.32747735e-02,
#          1.46604422e-02,  4.45817932e-02, -6.77856291e-03,
#          8.64909738e-02, -5.00659496e-02,  6.05830625e-02,
#         -5.85512519e-02, -7.41328374e-02, -4.07381281e-02,
#         -4.62190509e-02, -2.91668661e-02, -4.27213088e-02,
#         -8.50341916e-02, -7.91059509e-02, -6.71506599e-02,
#          1.28828017e-02, -1.12139061e-02, -2.05859430e-02,
#          2.96257101e-02, -1.02398887e-01, -7.77662396e-02,
#         -1.40929092e-02, -9.11662430e-02, -6.77241236e-02,
#         -7.13218153e-02, -2.31174957e-02, -5.25913984e-02,
#          5.41850226e-03,  4.89527360e-02, -1.23757459e-02,
#          9.59252100e-03, -2.92501189e-02,  6.46212921e-02,
#         -6.40202463e-02,  1.71411615e-02, -1.26278475e-01,
#          6.52319491e-02, -6.71177506e-02, -1.82377342e-02,
#          1.48606636e-02,  5.96186668e-02, -3.32654566e-02,
#          1.99540146e-03, -5.77870682e-02,  5.53884953e-02,
#          1.13689369e-02, -7.79620459e-05, -5.87577112e-02,
#          7.56517053e-02,  4.84508127e-02, -3.61890532e-02,
#         -1.79408665e-03,  2.08812468e-02,  2.92749479e-02,
#         -9.95378569e-02, -2.77001262e-02,  1.80020705e-02,
#          2.97355093e-02, -1.23234659e-01, -5.09306304e-02,
#         -3.30761299e-02, -5.26242852e-02, -3.00878249e-02,
#         -3.25103439e-02,  1.60111822e-02,  3.44622023e-02,
#          5.15305474e-02, -1.93752497e-02,  1.57669075e-02,
#         -3.71751264e-02, -5.06176986e-02,  2.44201999e-02,
#         -1.51907057e-01,  2.39913464e-02, -1.13003314e-01,
#          1.30787894e-01, -4.54162620e-02, -9.83388200e-02,
#         -1.24397818e-02,  5.24396077e-02, -1.16456941e-01,
#          3.62680256e-02,  1.95654272e-03, -1.14642255e-01,
#         -8.16667303e-02,  7.88934752e-02, -1.04228251e-01,
#         -6.75295442e-02, -6.10613637e-02, -8.38295445e-02,
#         -1.31067276e-01,  4.69972305e-02,  3.72825861e-02,
#         -4.98914123e-02,  8.17808285e-02,  3.24426554e-02,
#         -1.22130230e-01,  3.11189927e-02, -7.21874386e-02,
#         -1.13061234e-01,  1.23376660e-02,  7.12911040e-02,
#         -4.75360453e-02,  4.95079681e-02,  1.43659227e-02,
#         -4.67221104e-02, -1.09122954e-01, -1.99307594e-03,
#         -3.16081159e-02,  5.52820191e-02,  6.98578060e-02,
#          3.89518999e-02,  1.15182936e-01,  2.25902516e-02,
#          2.15961877e-02, -1.35523528e-02,  8.84871632e-02,
#          2.74604987e-02,  5.00014126e-02,  3.15750227e-03,
#         -6.46323934e-02, -7.36401677e-02, -9.05453321e-03,
#         -2.28001043e-01,  4.16552834e-02, -7.54309520e-02,
#          2.18629744e-02,  5.21304719e-02,  7.64516816e-02,
#          7.53603727e-02, -1.03571914e-01,  1.18187003e-01,
#          2.14495473e-02,  4.93886471e-02, -2.27750335e-02,
#          3.69624197e-02,  5.50020039e-02, -1.24344015e-02,
#          1.29382275e-02]], dtype=float32)>

# %% [markdown]
# > ## 2) 임베딩 행렬 생성
#
# * (10000, 250)

# %%
embedding_dim = 250

embedding_matrix = np.zeros((max_words, embedding_dim))

for word, i in word_index.items():
    embedding_vector = embeddings_index([word])
    if i < max_words:
        if embedding_vector is not None:
            # 임베딩 인덱스에 없는 단어는 모두 0이 됨
            embedding_matrix[i] = embedding_vector

# %% [markdown]
# * 확인

# %%
embedding_matrix.shape
# Out:
# (10000, 250)

# %% [markdown]
# # IV. Keras Embedding Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - Embedding Dimension : 250

# %%
from keras import models
from keras import layers

imdb = models.Sequential()

imdb.add(layers.Embedding(max_words,
                          embedding_dim,
                          input_length = maxlen))

imdb.add(layers.LSTM(16))
imdb.add(layers.Dropout(0.5))
imdb.add(layers.Dense(1, activation = 'sigmoid'))

# %%
imdb.layers[0].set_weights([embedding_matrix])
imdb.layers[0].trainable = False

# %% [markdown]
# * 모델 구조 확인

# %%
imdb.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2000, 250)         2500000
# _________________________________________________________________
# lstm (LSTM)                  (None, 16)                17088
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 2,517,105
# Trainable params: 17,105
# Non-trainable params: 2,500,000
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
imdb.compile(loss = 'binary_crossentropy',
             optimizer = 'adam',
             metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 25분

# %%
# %%time

Hist_imdb = imdb.fit(X_train, y_train,
                     epochs = 100,
                     batch_size = 512,
                     validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 30/30 [==============================] - 46s 458ms/step - loss: 0.6900 - accuracy: 0.5329 - val_loss: 0.6818 - val_accuracy: 0.5974
# Epoch 2/100
# 30/30 [==============================] - 13s 428ms/step - loss: 0.6761 - accuracy: 0.5988 - val_loss: 0.6178 - val_accuracy: 0.6688
# Epoch 3/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.6192 - accuracy: 0.6785 - val_loss: 0.5889 - val_accuracy: 0.6986
# Epoch 4/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.5849 - accuracy: 0.7134 - val_loss: 0.5605 - val_accuracy: 0.7247
# Epoch 5/100
# 30/30 [==============================] - 13s 429ms/step - loss: 0.5638 - accuracy: 0.7251 - val_loss: 0.5202 - val_accuracy: 0.7556
# Epoch 6/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.5228 - accuracy: 0.7574 - val_loss: 0.5027 - val_accuracy: 0.7630
# Epoch 7/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.5018 - accuracy: 0.7676 - val_loss: 0.4966 - val_accuracy: 0.7584
# Epoch 8/100
# 30/30 [==============================] - 13s 429ms/step - loss: 0.5008 - accuracy: 0.7676 - val_loss: 0.4715 - val_accuracy: 0.7846
# Epoch 9/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.4818 - accuracy: 0.7826 - val_loss: 0.4664 - val_accuracy: 0.7907
# Epoch 10/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.5094 - accuracy: 0.7571 - val_loss: 0.5103 - val_accuracy: 0.7680
# Epoch 11/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4938 - accuracy: 0.7785 - val_loss: 0.4647 - val_accuracy: 0.7857
# Epoch 12/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4713 - accuracy: 0.7851 - val_loss: 0.4561 - val_accuracy: 0.7922
# Epoch 13/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4673 - accuracy: 0.7931 - val_loss: 0.4519 - val_accuracy: 0.7931
# Epoch 14/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4664 - accuracy: 0.7919 - val_loss: 0.4538 - val_accuracy: 0.7944
# Epoch 15/100
# 30/30 [==============================] - 13s 434ms/step - loss: 0.4507 - accuracy: 0.8012 - val_loss: 0.4661 - val_accuracy: 0.7785
# Epoch 16/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.4560 - accuracy: 0.7988 - val_loss: 0.4566 - val_accuracy: 0.7962
# Epoch 17/100
# 30/30 [==============================] - 13s 433ms/step - loss: 0.4550 - accuracy: 0.7970 - val_loss: 0.4448 - val_accuracy: 0.7965
# Epoch 18/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4479 - accuracy: 0.8013 - val_loss: 0.4393 - val_accuracy: 0.7970
# Epoch 19/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.4367 - accuracy: 0.8071 - val_loss: 0.4348 - val_accuracy: 0.8061
# Epoch 20/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4329 - accuracy: 0.8119 - val_loss: 0.4590 - val_accuracy: 0.7838
# Epoch 21/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.4331 - accuracy: 0.8051 - val_loss: 0.4217 - val_accuracy: 0.8102
# Epoch 22/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4266 - accuracy: 0.8141 - val_loss: 0.4480 - val_accuracy: 0.7875
# Epoch 23/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4400 - accuracy: 0.8041 - val_loss: 0.4243 - val_accuracy: 0.8139
# Epoch 24/100
# 30/30 [==============================] - 13s 429ms/step - loss: 0.4255 - accuracy: 0.8135 - val_loss: 0.4382 - val_accuracy: 0.7971
# Epoch 25/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4170 - accuracy: 0.8177 - val_loss: 0.4095 - val_accuracy: 0.8195
# Epoch 26/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4183 - accuracy: 0.8205 - val_loss: 0.4447 - val_accuracy: 0.7906
# Epoch 27/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4284 - accuracy: 0.8102 - val_loss: 0.4814 - val_accuracy: 0.7636
# Epoch 28/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.4394 - accuracy: 0.8024 - val_loss: 0.4088 - val_accuracy: 0.8145
# Epoch 29/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4094 - accuracy: 0.8159 - val_loss: 0.4119 - val_accuracy: 0.8191
# Epoch 30/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.4103 - accuracy: 0.8235 - val_loss: 0.4064 - val_accuracy: 0.8159
# Epoch 31/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.4101 - accuracy: 0.8239 - val_loss: 0.4248 - val_accuracy: 0.8054
# Epoch 32/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.4215 - accuracy: 0.8100 - val_loss: 0.3979 - val_accuracy: 0.8254
# Epoch 33/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.4111 - accuracy: 0.8201 - val_loss: 0.3970 - val_accuracy: 0.8252
# Epoch 34/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4099 - accuracy: 0.8204 - val_loss: 0.3974 - val_accuracy: 0.8208
# Epoch 35/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3933 - accuracy: 0.8342 - val_loss: 0.3939 - val_accuracy: 0.8277
# Epoch 36/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.4043 - accuracy: 0.8266 - val_loss: 0.4119 - val_accuracy: 0.8093
# Epoch 37/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4234 - accuracy: 0.8111 - val_loss: 0.4221 - val_accuracy: 0.8138
# Epoch 38/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4154 - accuracy: 0.8227 - val_loss: 0.4296 - val_accuracy: 0.8138
# Epoch 39/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.4062 - accuracy: 0.8268 - val_loss: 0.3995 - val_accuracy: 0.8252
# Epoch 40/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3935 - accuracy: 0.8368 - val_loss: 0.3879 - val_accuracy: 0.8284
# Epoch 41/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3942 - accuracy: 0.8326 - val_loss: 0.4060 - val_accuracy: 0.8206
# Epoch 42/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3869 - accuracy: 0.8359 - val_loss: 0.3981 - val_accuracy: 0.8223
# Epoch 43/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3950 - accuracy: 0.8309 - val_loss: 0.3857 - val_accuracy: 0.8262
# Epoch 44/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3909 - accuracy: 0.8384 - val_loss: 0.3992 - val_accuracy: 0.8156
# Epoch 45/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3916 - accuracy: 0.8323 - val_loss: 0.3849 - val_accuracy: 0.8319
# Epoch 46/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3846 - accuracy: 0.8360 - val_loss: 0.3943 - val_accuracy: 0.8260
# Epoch 47/100
# 30/30 [==============================] - 13s 433ms/step - loss: 0.3852 - accuracy: 0.8395 - val_loss: 0.4359 - val_accuracy: 0.8134
# Epoch 48/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4064 - accuracy: 0.8248 - val_loss: 0.3848 - val_accuracy: 0.8345
# Epoch 49/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3859 - accuracy: 0.8430 - val_loss: 0.3999 - val_accuracy: 0.8236
# Epoch 50/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3795 - accuracy: 0.8433 - val_loss: 0.3963 - val_accuracy: 0.8223
# Epoch 51/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3820 - accuracy: 0.8399 - val_loss: 0.3918 - val_accuracy: 0.8230
# Epoch 52/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4009 - accuracy: 0.8301 - val_loss: 0.3758 - val_accuracy: 0.8370
# Epoch 53/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3747 - accuracy: 0.8428 - val_loss: 0.3774 - val_accuracy: 0.8381
# Epoch 54/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3826 - accuracy: 0.8440 - val_loss: 0.3796 - val_accuracy: 0.8352
# Epoch 55/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3756 - accuracy: 0.8412 - val_loss: 0.3779 - val_accuracy: 0.8375
# Epoch 56/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3769 - accuracy: 0.8420 - val_loss: 0.4171 - val_accuracy: 0.8146
# Epoch 57/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3731 - accuracy: 0.8431 - val_loss: 0.3746 - val_accuracy: 0.8365
# Epoch 58/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3760 - accuracy: 0.8427 - val_loss: 0.3827 - val_accuracy: 0.8331
# Epoch 59/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3765 - accuracy: 0.8433 - val_loss: 0.3685 - val_accuracy: 0.8404
# Epoch 60/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3708 - accuracy: 0.8431 - val_loss: 0.3923 - val_accuracy: 0.8218
# Epoch 61/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3894 - accuracy: 0.8310 - val_loss: 0.4064 - val_accuracy: 0.8206
# Epoch 62/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3674 - accuracy: 0.8422 - val_loss: 0.3746 - val_accuracy: 0.8393
# Epoch 63/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3575 - accuracy: 0.8553 - val_loss: 0.3662 - val_accuracy: 0.8420
# Epoch 64/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3711 - accuracy: 0.8400 - val_loss: 0.4649 - val_accuracy: 0.8297
# Epoch 65/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4109 - accuracy: 0.8245 - val_loss: 0.4027 - val_accuracy: 0.8262
# Epoch 66/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3737 - accuracy: 0.8417 - val_loss: 0.3884 - val_accuracy: 0.8359
# Epoch 67/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.4220 - accuracy: 0.8250 - val_loss: 0.3721 - val_accuracy: 0.8370
# Epoch 68/100
# 30/30 [==============================] - 13s 433ms/step - loss: 0.3689 - accuracy: 0.8487 - val_loss: 0.3693 - val_accuracy: 0.8394
# Epoch 69/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3578 - accuracy: 0.8506 - val_loss: 0.3776 - val_accuracy: 0.8315
# Epoch 70/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3789 - accuracy: 0.8410 - val_loss: 0.4692 - val_accuracy: 0.7731
# Epoch 71/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4716 - accuracy: 0.7739 - val_loss: 0.4701 - val_accuracy: 0.7793
# Epoch 72/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4132 - accuracy: 0.8172 - val_loss: 0.4182 - val_accuracy: 0.8137
# Epoch 73/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3876 - accuracy: 0.8375 - val_loss: 0.3695 - val_accuracy: 0.8365
# Epoch 74/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3599 - accuracy: 0.8504 - val_loss: 0.3696 - val_accuracy: 0.8417
# Epoch 75/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3615 - accuracy: 0.8489 - val_loss: 0.3624 - val_accuracy: 0.8438
# Epoch 76/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3580 - accuracy: 0.8519 - val_loss: 0.3759 - val_accuracy: 0.8368
# Epoch 77/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3634 - accuracy: 0.8524 - val_loss: 0.4321 - val_accuracy: 0.8050
# Epoch 78/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3830 - accuracy: 0.8378 - val_loss: 0.3656 - val_accuracy: 0.8405
# Epoch 79/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3602 - accuracy: 0.8538 - val_loss: 0.3663 - val_accuracy: 0.8428
# Epoch 80/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3701 - accuracy: 0.8480 - val_loss: 0.5055 - val_accuracy: 0.7940
# Epoch 81/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.4171 - accuracy: 0.8254 - val_loss: 0.3642 - val_accuracy: 0.8422
# Epoch 82/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3584 - accuracy: 0.8546 - val_loss: 0.3641 - val_accuracy: 0.8410
# Epoch 83/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3623 - accuracy: 0.8479 - val_loss: 0.3797 - val_accuracy: 0.8410
# Epoch 84/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3525 - accuracy: 0.8522 - val_loss: 0.3575 - val_accuracy: 0.8430
# Epoch 85/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3668 - accuracy: 0.8432 - val_loss: 0.3681 - val_accuracy: 0.8394
# Epoch 86/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3608 - accuracy: 0.8520 - val_loss: 0.3835 - val_accuracy: 0.8332
# Epoch 87/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3712 - accuracy: 0.8421 - val_loss: 0.3654 - val_accuracy: 0.8396
# Epoch 88/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3539 - accuracy: 0.8555 - val_loss: 0.3579 - val_accuracy: 0.8456
# Epoch 89/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3415 - accuracy: 0.8584 - val_loss: 0.3546 - val_accuracy: 0.8444
# Epoch 90/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3472 - accuracy: 0.8591 - val_loss: 0.3752 - val_accuracy: 0.8348
# Epoch 91/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3551 - accuracy: 0.8518 - val_loss: 0.4281 - val_accuracy: 0.8170
# Epoch 92/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3843 - accuracy: 0.8332 - val_loss: 0.3793 - val_accuracy: 0.8389
# Epoch 93/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3595 - accuracy: 0.8545 - val_loss: 0.3548 - val_accuracy: 0.8484
# Epoch 94/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3499 - accuracy: 0.8578 - val_loss: 0.3542 - val_accuracy: 0.8473
# Epoch 95/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3514 - accuracy: 0.8591 - val_loss: 0.3692 - val_accuracy: 0.8449
# Epoch 96/100
# 30/30 [==============================] - 13s 432ms/step - loss: 0.3313 - accuracy: 0.8646 - val_loss: 0.3592 - val_accuracy: 0.8447
# Epoch 97/100
# 30/30 [==============================] - 13s 430ms/step - loss: 0.3503 - accuracy: 0.8526 - val_loss: 0.3623 - val_accuracy: 0.8414
# Epoch 98/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3478 - accuracy: 0.8575 - val_loss: 0.3791 - val_accuracy: 0.8368
# Epoch 99/100
# 30/30 [==============================] - 13s 433ms/step - loss: 0.3407 - accuracy: 0.8583 - val_loss: 0.3526 - val_accuracy: 0.8511
# Epoch 100/100
# 30/30 [==============================] - 13s 431ms/step - loss: 0.3652 - accuracy: 0.8438 - val_loss: 0.4214 - val_accuracy: 0.8216
# CPU times: user 20min 51s, sys: 1min 8s, total: 22min
# Wall time: 21min 51s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_imdb.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_imdb.history['loss'])
plt.plot(epochs, Hist_imdb.history['val_loss'])
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# * Accuracy Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_imdb.history['accuracy']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_imdb.history['accuracy'])
plt.plot(epochs, Hist_imdb.history['val_accuracy'])
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = imdb.evaluate(X_valid, y_valid)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 11s 36ms/step - loss: 0.4214 - accuracy: 0.8216
# Loss = 0.42139
# Accuracy = 0.82160

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
