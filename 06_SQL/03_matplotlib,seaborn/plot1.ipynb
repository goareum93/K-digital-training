# %%
# !cd
# Out:
# C:\Users\admin\Desktop\2021-K-Digital-Training-main\SQL

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# nrows, ncols int, default: 1

# %%
fig, ax = plt.subplots()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
import pandas

# %%
a = pandas.DataFrame(np.random.rand(4, 5), columns = list('abcde'))
a_asarray = a.values
a_asarray
# Out:
# array([[0.17739112, 0.51793639, 0.819343  , 0.91094299, 0.86565784],
#        [0.68566932, 0.07344629, 0.35072301, 0.32973379, 0.65950408],
#        [0.47983159, 0.61205382, 0.99855323, 0.10829745, 0.13409636],
#        [0.06602358, 0.43650029, 0.37851587, 0.61278472, 0.78962015]])

# %%
a
# Out:
#           a         b         c         d         e
# 0  0.177391  0.517936  0.819343  0.910943  0.865658
# 1  0.685669  0.073446  0.350723  0.329734  0.659504
# 2  0.479832  0.612054  0.998553  0.108297  0.134096
# 3  0.066024  0.436500  0.378516  0.612785  0.789620

# %%
plt.plot(a)
# Out:
# [<matplotlib.lines.Line2D at 0x2660bcdf448>,
#  <matplotlib.lines.Line2D at 0x2660bcdf8c8>,
#  <matplotlib.lines.Line2D at 0x2660bce6948>,
#  <matplotlib.lines.Line2D at 0x2660bcd3f48>,
#  <matplotlib.lines.Line2D at 0x2660bce6bc8>]

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)

# %%
plt.plot(b)
# Out:
# [<matplotlib.lines.Line2D at 0x2660b8f98c8>,
#  <matplotlib.lines.Line2D at 0x2660b8f9d48>]

# %%
ax1 = plt.subplot(121)
graph = plt.plot(a_asarray)

ax1 = plt.subplot(122)
graph = plt.plot(b_asarray)

# %%
plt.subplot(121)
plt.plot(a_asarray)

plt.subplot(122)
plt.plot(b_asarray)

plt.show()

# %%
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
axs[0,0].plot([1, 2, 3, 4], [3, 2, 1, 2])
axs[1,0].plot([1, 2, 3, 4], [1, 4, 2, 3])
